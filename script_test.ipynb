# %%
import os
import configparser
config = configparser.ConfigParser()
config.read('./dl.cfg')
os.environ['AWS_ACCESS_KEY_ID']=config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0,saurfang:spark-sas7bdat:2.0.0-s_2.11") \
        .getOrCreate()

# %%
source_bucket = "s3a://udacity-data-source"
output_bucket = "s3a://dacity-debug-data-sink"

# %%
# %run -i "./dags/transform/labels.py"
# Out:
# countryCodes
# beginning found on line: 9
# Read 289 items
# portCodes
# beginning found on line: 302
# Read 660 items
#     Code                                    Port
# 0    ALC                               ALCAN, AK
# 1    ANC                           ANCHORAGE, AK
# 2    BAR            BAKER AAF - BAKER ISLAND, AK
# 3    DAC                       DALTONS CACHE, AK
# 4    PIZ              DEW STATION PT LAY DEW, AK
# 5    DTH                        DUTCH HARBOR, AK
# 6    EGL                               EAGLE, AK
# 7    FRB                           FAIRBANKS, AK
# 8    HOM                               HOMER, AK
# 9    HYD                               HYDER, AK
# 10   JUN                              JUNEAU, AK
# 11   5KE                           KETCHIKAN, AK
# 12   KET                           KETCHIKAN, AK
# 13   MOS            MOSES POINT INTERMEDIATE, AK
# 14   NIK                             NIKISKI, AK
# 15   NOM                                 NOM, AK
# ...

# %%
# %run -i "./dags/transform/airports.py"
# Out:
# Reading: s3a://udacity-data-source/airport-codes_csv.csv
# df_airport  55075
# df_airport_clean  21286
# +----------+-------------+-----------------------------+------------+-----------+-----+--------------+--------+------------+-------------------+-----------------+
# |airport_id|type         |name                         |elevation_ft|iso_country|state|municipality  |gps_code|airport_code|latitude           |longitude        |
# +----------+-------------+-----------------------------+------------+-----------+-----+--------------+--------+------------+-------------------+-----------------+
# |00MO      |small_airport|Cooper Flying Service Airport|970         |US         |MO   |Alba          |00MO    |null        |-94.412399291992   |37.202800750732  |
# |05NV      |small_airport|Baker Ranches Airport        |5180        |US         |NV   |Baker         |05NV    |null        |-114.088219        |39.0311          |
# ...

# %%
# %run -i "./dags/transform/states.py"
# Out:
# df_demographics  2891
# df_demographics_clean  2891
# +---------------+----------+----------+---------------+-----------------+----------------+------------------+----------------------+----------------------+----------+---------------------------------+------+
# |city           |state     |median_age|male_population|female_population|total_population|number_of_veterans|number_of_foreign_born|average_household_size|state_code|race                             |count |
# +---------------+----------+----------+---------------+-----------------+----------------+------------------+----------------------+----------------------+----------+---------------------------------+------+
# |Mesa           |Arizona   |36.9      |234998         |236835           |471833          |31808             |57492                 |2.68                  |AZ        |Hispanic or Latino               |131425|
# ...

# %%
month_year='jan16'
# %run -i "./dags/transform/immigration.py"
# Out:
# df_immigration_clean  2847924
# +------+-----+-------------+-----------------+----+------------+------------+-------------+--------------+-------------+--------------+----------+----------------------+----------+------------+--------------+-----------+---------------------------+----------+------------+----------+-------+----------------+-------------+---------+
# |year  |month|birth_country|residence_country|port|arrival_date|arrival_mode|us_state     |departure_date|repondent_age|visa_type_code|date_added|visa_issued_department|occupation|arrival_flag|departure_flag|update_flag|match_arrival_departure_fag|birth_year|allowed_date|ins_number|airline|admission_number|flight_number|visa_type|
# ...
